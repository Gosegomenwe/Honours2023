# %%
#get rid of annoying GPU warnings (and others)
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import cv2
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from sklearn import svm, metrics, datasets
from sklearn.utils import Bunch
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from numpy.random import seed
seed(42)
import tensorflow as tf
tf.random.set_seed(42)

import matplotlib.pyplot as plt      # MATLAB like plotting routines
import random                        # for generating random numbers

from keras.models import Sequential, model_from_json  # Model type to be used

from keras.layers.core import Dense, Dropout, Activation # Types of layers to be used in our model
from keras.utils import np_utils                         # NumPy related tools
from pathlib import Path

from keras.layers import Flatten
from keras.regularizers import l2
from keras.callbacks import LearningRateScheduler
from keras.callbacks import History
from keras.optimizers import Adam

from keras import losses
from sklearn.utils import shuffle

import numpy
from sklearn.model_selection import GridSearchCV
import keras_tuner as kt

# %% [markdown]
# **Get the data**

# %%
def load_image_files(container_path, dimension=(128,128)):
    image_dir = Path(container_path)
    folders = [directory for directory in image_dir.iterdir() if directory.is_dir()]
    categories = [fo.name for fo in folders]

    descr = "Your own dataset"
    images = []
    flat_data = []
    target = []
    for i, direc in enumerate(folders):
        for file in direc.iterdir():
            if file.suffix.lower() not in ['.jpg', '.jpeg', '.png','.webp','.gif']:
                print(f"Skipped non-image file: {file}")
                continue
            img = cv2.imread(str(file), cv2.IMREAD_COLOR)
            if img is None:
                print(f"Failed to read image: {file}")
                continue
            img_resized = cv2.resize(img, dimension, interpolation=cv2.INTER_AREA)
            
            if img_resized.size == 0:
                print(f"Empty image: {file}")
                continue
            flat_data.append(img_resized.flatten())
            images.append(img_resized)
            target.append(i)
    flat_data = np.array(flat_data)
    target = np.array(target)
    images = np.array(images)


    return Bunch(
        data=flat_data,
        target=target,
        target_names=categories,
        images=images,
        DESCR=descr
    )

# %%
image_dataset = load_image_files("/kaggle/input/soil-data-v3/Soil_Data_V3/Trains")
image_dataset_test = load_image_files("/kaggle/input/soil-data-v3/Soil_Data_V3/Tests")
# Out:
# Skipped non-image file: /kaggle/input/soil-data-v3/Soil_Data_V3/Trains/Mary/desktop.ini
# Skipped non-image file: /kaggle/input/soil-data-v3/Soil_Data_V3/Trains/Sand/desktop.ini
# Skipped non-image file: /kaggle/input/soil-data-v3/Soil_Data_V3/Trains/Silt/desktop.ini
# Skipped non-image file: /kaggle/input/soil-data-v3/Soil_Data_V3/Tests/Chalky/desktop.ini

# %% [markdown]
# **Split the data**

# %%
X_train = image_dataset.images
X_test = image_dataset_test.images
y_train = image_dataset.target
y_test=image_dataset_test.target

# %%
print(X_train.shape)
# Out:
# (3670, 128, 128, 3)

# %%
from keras.models import Sequential
from keras.regularizers import l2
from keras.layers import Conv2D, AveragePooling2D, Activation, Dropout, Flatten, BatchNormalization, Dense
from keras.optimizers import Adam

def create_model(hp):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=(128, 128, 3), kernel_regularizer=l2(hp.Float('weight_decay', min_value=1e-6, max_value=1e-2)))) # Use hp.Float for weight_decay choice
    model.add(BatchNormalization(axis=-1))
    model.add(Activation('relu'))

    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(BatchNormalization(axis=-1))
    model.add(Dropout(hp.Float('dropout_1', 0, 0.2)))  # Use hp.Float for dropout choice

    model.add(Conv2D(64, (3, 3), kernel_regularizer=l2(hp.Float('weight_decay', 1e-6, 1e-2))))  # Use hp.Float for weight_decay choice
    model.add(BatchNormalization(axis=-1))
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(BatchNormalization(axis=-1))
    model.add(Dropout(hp.Float('dropout_2', 0, 0.2)))  # Use hp.Float for dropout choice

    model.add(Conv2D(128, (3, 3), kernel_regularizer=l2(hp.Float('weight_decay', 1e-6, 1e-2))))  # Use hp.Float for weight_decay choice
    model.add(Conv2D(128, (3, 3), kernel_regularizer=l2(hp.Float('weight_decay', 1e-6, 1e-2))))
    model.add(BatchNormalization(axis=-1))
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dropout(hp.Float('dropout_3', 0,0.2)))  # Use hp.Float for dropout choice

    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(hp.Float('dropout_4', 0, 0.2)))  # Use hp.Float for dropout choice

    model.add(Dense(8))
    model.add(Activation('softmax'))

    # Compile the model
    model.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[1e-3, 1e-4, 1e-5])),
        metrics=['accuracy']
    )

    return model

# %%
from keras_tuner import HyperParameters

# Create a hyperparameter object
hp = HyperParameters()

# %%
seed = 42
numpy.random.seed(seed)
batch_size = 8
epochs = 30

from keras import callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss",
                                        mode="min", patience=10,
                                        restore_best_weights=True)

# %%
model=create_model(hp)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  activation (Activation)     (None, 126, 126, 32)      0
#
#  average_pooling2d (AverageP  (None, 63, 63, 32)       0
#  ooling2D)
#
#  batch_normalization_1 (Batc  (None, 63, 63, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 61, 61, 64)        0
#
#  average_pooling2d_1 (Averag  (None, 30, 30, 64)       0
#  ePooling2D)
#
#  batch_normalization_3 (Batc  (None, 30, 30, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 128)       147584
#
#  batch_normalization_4 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 26, 26, 128)       0
#
#  average_pooling2d_2 (Averag  (None, 13, 13, 128)      0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dropout_2 (Dropout)         (None, 21632)             0
#
#  dense (Dense)               (None, 512)               11076096
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 8)                 4104
#
#  activation_4 (Activation)   (None, 8)                 0
#
# =================================================================
# Total params: 11,324,360
# Trainable params: 11,322,696
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
from keras_tuner.tuners import RandomSearch
# Create a tuner and start the hyperparameter search
tuner = RandomSearch(
    create_model,
    objective='val_accuracy',
    max_trials=10,
    directory='my_dir',
    project_name='my_project'
)

# Perform the hyperparameter search
tuner.search(X_train, y_train, epochs=80, validation_data=(X_test, y_test))
# Out:
# Trial 10 Complete [00h 04m 07s]
# val_accuracy: 0.8699495196342468
#
# Best val_accuracy So Far: 0.8844696879386902
# Total elapsed time: 00h 32m 48s

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best Hyperparameters:", best_hps.values)
# Out:
# Best Hyperparameters: {'weight_decay': 0.004892610191809718, 'dropout_1': 0.15677940817371858, 'dropout_2': 0.08969994181401919, 'dropout_3': 0.08548384513232879, 'dropout_4': 0.022332840753152984, 'learning_rate': 0.0001}

# %%
import time
best_model = tuner.hypermodel.build(best_hps)
start_time=time.time()
best_model.fit(X_train, y_train,batch_size=8, epochs=80, validation_data=(X_test, y_test),callbacks=[earlystopping])
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed Time:", round(elapsed_time, 2), "seconds")
# Out:
# Epoch 1/80
# 459/459 [==============================] - 6s 11ms/step - loss: 2.5019 - accuracy: 0.5777 - val_loss: 2.3321 - val_accuracy: 0.6395
# Epoch 2/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.8486 - accuracy: 0.7959 - val_loss: 1.8664 - val_accuracy: 0.7797
# Epoch 3/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.5530 - accuracy: 0.8689 - val_loss: 1.8042 - val_accuracy: 0.7980
# Epoch 4/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.3803 - accuracy: 0.9084 - val_loss: 1.6086 - val_accuracy: 0.8346
# Epoch 5/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.2654 - accuracy: 0.9281 - val_loss: 1.7660 - val_accuracy: 0.8131
# Epoch 6/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.1760 - accuracy: 0.9346 - val_loss: 1.5459 - val_accuracy: 0.8479
# Epoch 7/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.0861 - accuracy: 0.9441 - val_loss: 1.3859 - val_accuracy: 0.8712
# Epoch 8/80
# 459/459 [==============================] - 5s 10ms/step - loss: 1.0158 - accuracy: 0.9488 - val_loss: 1.3477 - val_accuracy: 0.8668
# Epoch 9/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.9408 - accuracy: 0.9572 - val_loss: 1.3186 - val_accuracy: 0.8706
# Epoch 10/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.8693 - accuracy: 0.9599 - val_loss: 1.2445 - val_accuracy: 0.8649
# Epoch 11/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.7828 - accuracy: 0.9692 - val_loss: 1.2001 - val_accuracy: 0.8693
# Epoch 12/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.7496 - accuracy: 0.9646 - val_loss: 1.1855 - val_accuracy: 0.8668
# Epoch 13/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.6791 - accuracy: 0.9700 - val_loss: 1.1724 - val_accuracy: 0.8592
# Epoch 14/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.6427 - accuracy: 0.9676 - val_loss: 1.1200 - val_accuracy: 0.8611
# Epoch 15/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.6065 - accuracy: 0.9651 - val_loss: 1.1793 - val_accuracy: 0.8365
# Epoch 16/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.5469 - accuracy: 0.9719 - val_loss: 1.0594 - val_accuracy: 0.8611
# Epoch 17/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.5138 - accuracy: 0.9719 - val_loss: 0.9202 - val_accuracy: 0.8763
# Epoch 18/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.4945 - accuracy: 0.9717 - val_loss: 1.0922 - val_accuracy: 0.8586
# Epoch 19/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.4494 - accuracy: 0.9763 - val_loss: 0.9860 - val_accuracy: 0.8535
# Epoch 20/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.4244 - accuracy: 0.9730 - val_loss: 0.9116 - val_accuracy: 0.8668
# Epoch 21/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.3913 - accuracy: 0.9744 - val_loss: 0.8705 - val_accuracy: 0.8744
# Epoch 22/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.3587 - accuracy: 0.9782 - val_loss: 0.8817 - val_accuracy: 0.8819
# Epoch 23/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.3449 - accuracy: 0.9787 - val_loss: 0.8279 - val_accuracy: 0.8838
# Epoch 24/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.3380 - accuracy: 0.9719 - val_loss: 0.8144 - val_accuracy: 0.8668
# Epoch 25/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.2939 - accuracy: 0.9820 - val_loss: 0.8677 - val_accuracy: 0.8725
# Epoch 26/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.2980 - accuracy: 0.9774 - val_loss: 0.7503 - val_accuracy: 0.8706
# Epoch 27/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.2781 - accuracy: 0.9790 - val_loss: 0.7055 - val_accuracy: 0.8775
# Epoch 28/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.2626 - accuracy: 0.9779 - val_loss: 0.9444 - val_accuracy: 0.8409
# Epoch 29/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.2707 - accuracy: 0.9719 - val_loss: 0.8278 - val_accuracy: 0.8649
# Epoch 30/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.2411 - accuracy: 0.9782 - val_loss: 0.7374 - val_accuracy: 0.8725
# Epoch 31/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.2306 - accuracy: 0.9823 - val_loss: 0.7321 - val_accuracy: 0.8636
# Epoch 32/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.2087 - accuracy: 0.9807 - val_loss: 0.7830 - val_accuracy: 0.8655
# Epoch 33/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.2148 - accuracy: 0.9771 - val_loss: 0.8292 - val_accuracy: 0.8668
# Epoch 34/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.1967 - accuracy: 0.9804 - val_loss: 0.7161 - val_accuracy: 0.8655
# Epoch 35/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.2077 - accuracy: 0.9782 - val_loss: 0.8316 - val_accuracy: 0.8674
# Epoch 36/80
# 459/459 [==============================] - 4s 10ms/step - loss: 0.1814 - accuracy: 0.9826 - val_loss: 0.8261 - val_accuracy: 0.8567
# Epoch 37/80
# 459/459 [==============================] - 5s 10ms/step - loss: 0.1754 - accuracy: 0.9815 - val_loss: 0.7714 - val_accuracy: 0.8668
# Elapsed Time: 170.02 seconds

# %%
start_time=time.time()
score = best_model.evaluate(X_test, y_test)                   
print('Test score:', score[0])
print('Test accuracy:', round(score[1]*100,2))
end_time = time.time()
elapsed_time = end_time - start_time
print("Elapsed Time:", round(elapsed_time, 2), "seconds")
# Out:
# 50/50 [==============================] - 1s 6ms/step - loss: 0.7055 - accuracy: 0.8775
# Test score: 0.7055201530456543
# Test accuracy: 87.75
# Elapsed Time: 0.63 seconds

# %%
from keras.models import save_model
best_model.save('optimal_cnn.h5')
